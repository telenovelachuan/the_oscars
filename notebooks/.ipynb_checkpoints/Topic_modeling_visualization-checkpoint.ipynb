# %% [markdown]
# This notebook contains advanced rendering function, please use jupyter nbviewer

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD, LatentDirichletAllocation
from sklearn.manifold import TSNE
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

SELF_DEFINED_STOP_WORDS = ['thy', 'thou', 'thee', 'sir', 'shall']
TOPIC_COLOR_MAP = np.array([
    "#1f77b5", "#aec7e9", "#ff7f0f", "#ffbb79", "#2ca02d", "#98df8b", "#d62729", "#ff9897", "#9467be", "#c5b0d6",
    "#8c564c", "#c49c95", "#e377c3", "#f7b6d3", "#7f7f80", "#c7c7c8", "#bcbd23", "#dbdb8e", "#17bed0", "#9edae6"
])

def get_keys(topic_matrix):
    keys = topic_matrix.argmax(axis=1).tolist()
    return keys

def _get_mean_topic_vectors(keys, two_dim_vectors):
        '''
        returns a list of centroid vectors from each predicted topic category
        '''
        centroid_topic_vectors = []
        for t in range(n_components):
            articles_in_that_topic = []
            for i in range(len(keys)):
                if keys[i] == t:
                    articles_in_that_topic.append(two_dim_vectors[i])

            articles_in_that_topic = np.vstack(articles_in_that_topic)
            centroid_article_in_that_topic = np.mean(articles_in_that_topic, axis=0)
            centroid_topic_vectors.append(centroid_article_in_that_topic)
        return centroid_topic_vectors
    
def get_top_n_words(n, n_topics, document_term_matrix, keys, count_vectorizer):
    top_word_indices = []
    for topic in range(n_topics):
        temp_vector_sum = 0
        for i in range(len(keys)):
            if keys[i] == topic:
                temp_vector_sum += document_term_matrix[i]
        temp_vector_sum = temp_vector_sum.toarray()
        top_n_word_indices = np.flip(np.argsort(temp_vector_sum)[0][-n:], 0)
        top_word_indices.append(top_n_word_indices)
    top_words = []
    for topic in top_word_indices:
        topic_words = []
        for index in topic:
            temp_word_vector = np.zeros((1, document_term_matrix.shape[1]))
            temp_word_vector[:, index] = 1
            the_word = count_vectorizer.inverse_transform(temp_word_vector)[0][0]
            topic_words.append(the_word.encode('ascii').decode('utf-8'))
        top_words.append(" ".join(topic_words))
    return top_words

# %%
df = pd.read_csv("../data/processed/processed.csv")
df.dropna(subset=['PlayerLine'], inplace=True)
print "Load the processed data of the Shakespear playerline data set"
df.head()
# Out:
# Load the processed data of the Shakespear playerline data set
#    Dataline      Play  Play_length  PlayerLinenumber ActSceneLine  ASL_1  \
# 0         1  Henry IV            8               NaN          NaN    NaN
# 1         2  Henry IV            8               NaN          NaN    NaN
# 2         3  Henry IV            8               NaN          NaN    NaN
# 3         4  Henry IV            8               1.0        1.1.1    1.0
# 4         5  Henry IV            8               1.0        1.1.2    1.0
#
#    ASL_2  ASL_3         Player  PL_length  PL_w_count  PL_w_density  \
# 0    NaN    NaN            NaN          5           2      2.500000
# 1    NaN    NaN            NaN         28           5      5.600000
# 2    NaN    NaN            NaN         96          16      6.000000
# 3    1.0    1.0  KING HENRY IV         38           9      4.222222
# 4    1.0    2.0  KING HENRY IV         42           9      4.666667
#
#                                           PlayerLine  PL_contain_!  \
# 0                                              ACT I         False
# 1                       SCENE I. London. The palace.         False
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...         False
# 3             So shaken as we are, so wan with care,         False
# 4         Find we a time for frighted peace to pant,         False
#
#    PL_contain_?  PL_#_comma_split  PL_#_stop_words  PL_#_upper_case
# 0         False                 1                1                4
# 1         False                 1                1                8
# 2         False                 5                4               59
# 3         False                 3                5                1
# 4         False                 2                4                1

# %% [markdown]
# Training LDA model on the playerline text

# %%
df_hamplet = df[df['Play'] == 'Hamlet']
playerlines = df_hamplet['PlayerLine']
count_vectorizer_limited = CountVectorizer(stop_words='english', max_features=40000)
document_term_matrix = count_vectorizer_limited.fit_transform(playerlines)
print "term matrix generated"
LDA_model = LatentDirichletAllocation(learning_method='online', n_components=14, random_state=0, verbose=0)
print "LDA model initialized"
topic_matrix = LDA_model.fit_transform(document_term_matrix)
print "LDA model trained"
# Out:
# term matrix generated
# LDA model initialized
# LDA model trained

# %%
Use tsne to reduce dimension to 2, and visualize 2-dimention data points

# %%
tsne_model = TSNE(n_components=2, perplexity=50, learning_rate=100, n_iter=2000, verbose=0, random_state=0, angle=0.75)
tsne_vectors = tsne_model.fit_transform(topic_matrix)

# %%
n_components = 14
keys = get_keys(topic_matrix)
mean_topic_vectors = _get_mean_topic_vectors(keys, tsne_vectors)

# %%
colormap = TOPIC_COLOR_MAP[:n_components]
top_3_words = get_top_n_words(3, n_components, document_term_matrix, keys, count_vectorizer_limited)
fig, ax = plt.subplots(figsize=(16, 16))
plt.scatter(x=tsne_vectors[:, 0], y=tsne_vectors[:, 1],color=colormap[keys],marker='o', alpha=0.5)
for t in range(n_components):
    plt.text(mean_topic_vectors[t][0], mean_topic_vectors[t][1], top_3_words[t], color=colormap[t],  horizontalalignment='center', weight='bold')
plt.show()

# %%
#df_asl_1 = df[df['ASL_1'] == 1]
df_GLOUCESTER = df[df['Player'] == 'GLOUCESTER']
n_components = 10;
playerlines = df_GLOUCESTER['PlayerLine']
count_vectorizer_limited = CountVectorizer(stop_words='english', max_features=40000)
document_term_matrix = count_vectorizer_limited.fit_transform(playerlines)
print "term matrix generated"
LDA_model = LatentDirichletAllocation(learning_method='online', n_components=n_components, random_state=0, verbose=0)
print "LDA model initialized"
topic_matrix = LDA_model.fit_transform(document_term_matrix)
print "LDA model trained"
tsne_model = TSNE(n_components=2, perplexity=50, learning_rate=100, n_iter=2000, verbose=0, random_state=0, angle=0.75)
tsne_vectors = tsne_model.fit_transform(topic_matrix)
keys = get_keys(topic_matrix)
mean_topic_vectors = _get_mean_topic_vectors(keys, tsne_vectors)
colormap = TOPIC_COLOR_MAP[:n_components]
top_3_words = get_top_n_words(3, n_components, document_term_matrix, keys, count_vectorizer_limited)
fig, ax = plt.subplots(figsize=(16, 16))
plt.scatter(x=tsne_vectors[:, 0], y=tsne_vectors[:, 1],color=colormap[keys],marker='o', alpha=0.5)
for t in range(n_components):
    plt.text(mean_topic_vectors[t][0], mean_topic_vectors[t][1], top_3_words[t], color=colormap[t],  horizontalalignment='center', weight='bold')
plt.show()
# Out:
# term matrix generated
# LDA model initialized
# LDA model trained

# %%
from __future__ import print_function
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook
# 1419  Topic10   2.326453       manner   2.976301   2.3544  -5.3641
# 1746  Topic10   2.310251         prey   2.960038   2.3529  -5.3711
# 304   Topic10   2.238909        brows   2.888642   2.3460  -5.4025
# 366   Topic10   2.196708       charge   2.846449   2.3417  -5.4215
# 926   Topic10   2.194430         foot   2.844285   2.3414  -5.4226
# 673   Topic10   2.162487  dissembling   2.812182   2.3381  -5.4372
# 2140  Topic10   2.144078       spring   2.793732   2.3361  -5.4458
# 2244  Topic10   2.121899    suspicion   2.771648   2.3336  -5.4562
# 1048  Topic10   2.055308      guarded   2.704958   2.3261  -5.4881
# 336   Topic10   2.038615      captain   2.688323   2.3241  -5.4962
# 1271  Topic10   2.691985        knave   3.969878   2.2123  -5.2182
# 339   Topic10   4.375983     cardinal   8.074450   1.9882  -4.7324
#
# [398 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 16        7  0.862350       accuse
# 32        7  0.647684  adversaries
# 46        1  0.316624           ah
# 46        3  0.633248           ah
# 51        4  0.347696        alack
# 51        8  0.695391        alack
# 75        6  0.828063      ancient
# 82        7  0.930556       answer
# 98        7  0.871567         arms
# 102       6  0.837780          art
# 106       2  0.983239        aside
# 123       3  0.908848         away
# 128       2  0.352202           ay
# 128       4  0.616353           ay
# 130       6  0.947404          bad
# 150       4  0.888302         bear
# 159       2  0.822310       beauty
# 160       2  0.962204          bed
# 163       9  0.680721          beg
# 166       6  0.920632        begin
# 179       5  0.968470      beseech
# 183       5  0.945858         best
# 188       3  0.916319       better
# 196       3  0.890490          bid
# 201       6  0.972218       bishop
# 220       6  0.730808        blind
# 222       8  0.970732        blood
# 223       7  0.944065       bloody
# 236       7  0.858801         body
# 250       6  0.804330         born
# ...     ...       ...          ...
# 2417      8  0.782477         unto
# 2451      9  0.932738      villain
# 2454      3  0.917514       virtue
# 2458     10  0.876328        voice
# 2469      4  0.795801         want
# 2479     10  0.897746      warwick
# 2482      7  0.950155          way
# 2486      3  0.926320         wear
# 2496      1  0.927067      welcome
# 2508      7  0.910263       whiles
# 2519      2  0.788992        widow
# 2520      5  0.857186         wife
# 2539      9  0.817254         wise
# 2540      2  0.897352         wish
# 2544     10  0.645763       withal
# 2545      8  0.670433       wither
# 2547      4  0.792367      witness
# 2554      6  0.795925        woman
# 2557      7  0.882851        women
# 2559      5  0.742302       wonder
# 2565      5  0.966673         word
# 2566      6  0.889173        words
# 2568      4  0.937998        world
# 2572      5  0.834154        worse
# 2595      9  0.814265        wrong
# 2598      4  0.661752           ye
# 2598      5  0.330876           ye
# 2599      2  0.856835          yea
# 2607     10  0.928641         york
# 2608      1  0.912963        young
#
# [410 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 9, 8, 3, 7, 2, 4, 1, 10, 5])

# %%
pyLDAvis.sklearn.prepare(LDA_model, document_term_matrix, count_vectorizer_limited, mds='tsne')
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics           x           y
# topic
# 5      13.241969        1       1   40.235592   48.866417
# 8      12.572400        1       2   13.292131  -96.549660
# 7      11.473590        1       3   33.028282  132.765198
# 2      11.304434        1       4   -2.616741  -17.721205
# 6      10.236558        1       5  -81.828926  -46.177528
# 1       9.631960        1       6  -38.917889   52.721951
# 3       8.300489        1       7   88.615128  -29.214058
# 0       8.101710        1       8  -61.532314  131.424988
# 9       7.715323        1       9 -119.879158   40.365566
# 4       7.421567        1      10  118.484390   67.377304, topic_info=     Category       Freq         Term      Total  loglift  logprob
# 1373  Default  46.000000         lord  46.000000  30.0000  30.0000
# 2009  Default  40.000000        shall  40.000000  29.0000  29.0000
# 1266  Default  56.000000         king  56.000000  28.0000  28.0000
# 2299  Default  56.000000         thou  56.000000  27.0000  27.0000
# 1093  Default  31.000000         hath  31.000000  26.0000  26.0000
# 782   Default  28.000000        enter  28.000000  25.0000  25.0000
# 1011  Default  32.000000         good  32.000000  24.0000  24.0000
# 2313  Default  55.000000          thy  55.000000  23.0000  23.0000
# 2284  Default  42.000000         thee  42.000000  22.0000  22.0000
# 1326  Default  25.000000          let  25.000000  21.0000  21.0000
# 1953  Default  24.000000          say  24.000000  20.0000  20.0000
# 408   Default  31.000000     clarence  31.000000  19.0000  19.0000
# 1003  Default  24.000000          god  24.000000  18.0000  18.0000
# 435   Default  19.000000         come  19.000000  17.0000  17.0000
# 298   Default  18.000000      brother  18.000000  16.0000  16.0000
# 641   Default  18.000000          did  18.000000  15.0000  15.0000
# 861   Default  16.000000       father  16.000000  14.0000  14.0000
# 106   Default  20.000000        aside  20.000000  13.0000  13.0000
# 1345  Default  16.000000         like  16.000000  12.0000  12.0000
# 832   Default  18.000000         eyes  18.000000  11.0000  11.0000
# 1416  Default  20.000000          man  20.000000  10.0000  10.0000
# 2568  Default  18.000000        world  18.000000   9.0000   9.0000
# 746   Default  23.000000       edward  23.000000   8.0000   8.0000
# 1410  Default  16.000000         make  16.000000   7.0000   7.0000
# 1382  Default  20.000000         love  20.000000   6.0000   6.0000
# 1106  Default  19.000000        heart  19.000000   5.0000   5.0000
# 579   Default  12.000000          day  12.000000   4.0000   4.0000
# 1290  Default  15.000000         lady  15.000000   3.0000   3.0000
# 589   Default  16.000000        death  16.000000   2.0000   2.0000
# 963   Default  12.000000      friends  12.000000   1.0000   1.0000
# ...       ...        ...          ...        ...      ...      ...
# 2607  Topic10   7.963396         york   8.614740   2.5222  -4.1336
# 1533  Topic10   7.695358       nature   8.345149   2.5197  -4.1679
# 848   Topic10   6.145193        false   6.795285   2.5002  -4.3928
# 2479  Topic10   6.029327      warwick   6.683408   2.4978  -4.4119
# 1162  Topic10   5.832515        house   6.482284   2.4952  -4.4450
# 1305  Topic10   5.791568          law   6.441611   2.4944  -4.4521
# 947   Topic10   3.666067      forward   4.315814   2.4376  -4.9094
# 1786  Topic10   3.466389        prove   4.116201   2.4290  -4.9654
# 1323  Topic10   3.227364         legs   3.877044   2.4174  -5.0368
# 892   Topic10   3.036470        finds   3.686266   2.4069  -5.0978
# 1008  Topic10   2.962745       golden   3.613284   2.4023  -5.1224
# 768   Topic10   2.801560        enemy   3.451308   2.3922  -5.1783
# 1703  Topic10   2.785111        pluck   3.434890   2.3911  -5.1842
# 2458  Topic10   2.773398        voice   3.423376   2.3902  -5.1884
# 2544  Topic10   2.447443       withal   3.097110   2.3654  -5.3134
# 1600  Topic10   2.389436        order   3.039215   2.3602  -5.3374
# 627   Topic10   2.385490      deserve   3.035580   2.3598  -5.3391
# 2283  Topic10   2.343407       thanks   2.993357   2.3560  -5.3569
# 1419  Topic10   2.326453       manner   2.976301   2.3544  -5.3641
# 1746  Topic10   2.310251         prey   2.960038   2.3529  -5.3711
# 304   Topic10   2.238909        brows   2.888642   2.3460  -5.4025
# 366   Topic10   2.196708       charge   2.846449   2.3417  -5.4215
# 926   Topic10   2.194430         foot   2.844285   2.3414  -5.4226
# 673   Topic10   2.162487  dissembling   2.812182   2.3381  -5.4372
# 2140  Topic10   2.144078       spring   2.793732   2.3361  -5.4458
# 2244  Topic10   2.121899    suspicion   2.771648   2.3336  -5.4562
# 1048  Topic10   2.055308      guarded   2.704958   2.3261  -5.4881
# 336   Topic10   2.038615      captain   2.688323   2.3241  -5.4962
# 1271  Topic10   2.691985        knave   3.969878   2.2123  -5.2182
# 339   Topic10   4.375983     cardinal   8.074450   1.9882  -4.7324
#
# [398 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 16        7  0.862350       accuse
# 32        7  0.647684  adversaries
# 46        1  0.316624           ah
# 46        3  0.633248           ah
# 51        4  0.347696        alack
# 51        8  0.695391        alack
# 75        6  0.828063      ancient
# 82        7  0.930556       answer
# 98        7  0.871567         arms
# 102       6  0.837780          art
# 106       2  0.983239        aside
# 123       3  0.908848         away
# 128       2  0.352202           ay
# 128       4  0.616353           ay
# 130       6  0.947404          bad
# 150       4  0.888302         bear
# 159       2  0.822310       beauty
# 160       2  0.962204          bed
# 163       9  0.680721          beg
# 166       6  0.920632        begin
# 179       5  0.968470      beseech
# 183       5  0.945858         best
# 188       3  0.916319       better
# 196       3  0.890490          bid
# 201       6  0.972218       bishop
# 220       6  0.730808        blind
# 222       8  0.970732        blood
# 223       7  0.944065       bloody
# 236       7  0.858801         body
# 250       6  0.804330         born
# ...     ...       ...          ...
# 2417      8  0.782477         unto
# 2451      9  0.932738      villain
# 2454      3  0.917514       virtue
# 2458     10  0.876328        voice
# 2469      4  0.795801         want
# 2479     10  0.897746      warwick
# 2482      7  0.950155          way
# 2486      3  0.926320         wear
# 2496      1  0.927067      welcome
# 2508      7  0.910263       whiles
# 2519      2  0.788992        widow
# 2520      5  0.857186         wife
# 2539      9  0.817254         wise
# 2540      2  0.897352         wish
# 2544     10  0.645763       withal
# 2545      8  0.670433       wither
# 2547      4  0.792367      witness
# 2554      6  0.795925        woman
# 2557      7  0.882851        women
# 2559      5  0.742302       wonder
# 2565      5  0.966673         word
# 2566      6  0.889173        words
# 2568      4  0.937998        world
# 2572      5  0.834154        worse
# 2595      9  0.814265        wrong
# 2598      4  0.661752           ye
# 2598      5  0.330876           ye
# 2599      2  0.856835          yea
# 2607     10  0.928641         york
# 2608      1  0.912963        young
#
# [410 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 9, 8, 3, 7, 2, 4, 1, 10, 5])
